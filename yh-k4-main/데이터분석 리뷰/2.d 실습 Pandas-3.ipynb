# %% [markdown]
# winemag-data-130k-v2.csv 파일을 reviews 로 읽는다.

# %%
import calendar
import numpy as np
import pandas as pd
#from pandas.core.frame import DataFrame
#from pandas.core.series import Series #이렇게 불러도 됨.
import seaborn as sns # 통계적 plot
from scipy import stats #통계
import missingno as msno #결측치 보는 plot
from datetime import datetime #day
import matplotlib.pyplot as plt
import warnings #에러는 아닌데 주희하는게 뜨는것을 방지.
warnings.filterwarnings('ignore')

# %%
import pandas as pd
reviews = pd.read_csv('C:/Users/405/my_study/yh-k4-main/data/winemag-data.csv', index_col= 0)
reviews
# Out:
#          country                                        description
# 0          Italy  Aromas include tropical fruit, broom, brimston...  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price
# 0                                 Vulkà Bianco      87    NaN  \
# ...

# %% [markdown]
# 리뷰 데이터프레임에서 points 컬럼의  median 값은?

# %%
reviews['points'].median()
# Out:
# 88.0

# %% [markdown]
# 나라를 중복되지 않도록 가져와서 countries 변수에 저장하고, 화면에 출력하시오.

# %%
countries = reviews['country'].dropna().unique()
countries
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', 'Turkey', 'Czech Republic', 'Slovenia', 'Luxembourg',
#        'Croatia', 'Georgia', 'Uruguay', 'England', 'Lebanon', 'Serbia',
#        'Brazil', 'Moldova', 'Morocco', 'Peru', 'India', 'Bulgaria',
#        'Cyprus', 'Armenia', 'Switzerland', 'Bosnia and Herzegovina',
#        'Ukraine', 'Slovakia', 'Macedonia', 'China', 'Egypt'], dtype=object)

# %% [markdown]
# 각 국가별로는 몇개의 리뷰가 있는지, 각국가별 리뷰수를 구하시오.

# %%
reviews.groupby('country')['country'].count().sort_values()
# Out:
# country
# China                         1
# Slovakia                      1
# Egypt                         1
# Armenia                       2
# Bosnia and Herzegovina        2
# Luxembourg                    6
# Switzerland                   7
# India                         9
# Cyprus                       11
# Czech Republic               12
# Serbia                       12
# Macedonia                    12
# Ukraine                      14
# Peru                         16
# Morocco                      28
# Lebanon                      35
# Brazil                       52
# Moldova                      59
# Mexico                       70
# Croatia                      73
# England                      74
# Georgia                      86
# Slovenia                     87
# Turkey                       90
# Uruguay                     109
# Romania                     120
# Bulgaria                    141
# Hungary                     146
# Canada                      257
# ...

# %%
reviews['country'].value_counts()
# Out:
# country
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
reviews.loc['description']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\405\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\405\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\405\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'description'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ...

# %% [markdown]
# 리뷰 데이터프레임의 price 컬럼 값에서, price의 평균값을 뺀 값을, centered_price 라고 저장하시오.

# %%
centered_price = reviews['price'] - reviews['price'].mean()
centered_price
# Out:
# 0                  NaN
# 1        -2.644830e-73
# 2        -2.843563e-73
# 3        -3.042295e-73
# 4         7.291783e-73
#               ...
# 129966   -4.091400e-73
# 129967   -1.515776e-73
# 129968   -3.981799e-73
# 129969   -3.872198e-73
# 129970   -4.475004e-73
# Name: price, Length: 129971, dtype: float64

# %% [markdown]
# 나는 경제적이므로, 가격대비 포인트가 가장 큰 와인을 사려한다. 해당 와인의 title은?

# %%
reviews
# Out:
#          country                                        description
# 0          Italy  Aromas include tropical fruit, broom, brimston...  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price
# 0                                 Vulkà Bianco      87    NaN  \
# ...

# %%
reviews['가성비'] = reviews['points'] / reviews['price']
reviews.sort_values('가성비', ascending=False)
# Out:
#          country                                        description
# 64590         US  There's a lot going on in this Merlot, which i...  \
# 126096   Romania  Notes of sun-dried hay and green flower highli...
# 20484         US  Fruity, soft and rather sweet, this wine smell...
# 1987       Spain  Berry and cherry aromas are surprisingly sturd...
# 110255        US  A good everyday Merlot, dry and rich in tannin...
# ...          ...                                                ...
# 129844     Italy  Doga delle Clavule is a neutral, mineral-drive...
# 129860  Portugal  This rich wine has a firm structure as well as...
# 129863  Portugal  This mature wine that has 50% Touriga Nacional...
# 129893     Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964    France  Initially quite muted, this wine slowly develo...
#
#                          designation  points  price         province
# 64590                            NaN      86    4.0       California  \
# ...

# %% [markdown]
# 사람들이 어떤와인을 더 많이 거론했는지 보려한다.
#
# "tropical" 이 들어있는 리뷰의 갯수를 세고, "fruity" 라고 들어있는 리뷰의 갯수를 세어서
#
# 판다스 시리즈로 descriptor_counts 변수로 만들어 보자.

# %%
reviews['description']
# Out:
# 0         Aromas include tropical fruit, broom, brimston...
# 1         This is ripe and fruity, a wine that is smooth...
# 2         Tart and snappy, the flavors of lime flesh and...
# 3         Pineapple rind, lemon pith and orange blossom ...
# 4         Much like the regular bottling from 2012, this...
#                                 ...
# 129966    Notes of honeysuckle and cantaloupe sweeten th...
# 129967    Citation is given as much as a decade of bottl...
# 129968    Well-drained gravel soil gives this wine its c...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 129971, dtype: object

# %%
a = reviews['description'].str.contains('tropical', na=False).sum()
b = reviews['description'].str.contains('fruity', na=False).sum()  #contains : 문자열을 포함하는지 여부를 판별하기 위해 사용되는 메서드입니다

c = pd.Series({'tropical': a, 'fruity': b})
c
# Out:
# tropical    3607
# fruity      9090
# dtype: int64

# %%
# apply(함수명) 함수는 pandas의 데이터프레임 또는 시리즈에 적용되는 메서드로, 사용자가 지정한 함수를 각 요소 또는 축(axis)에 적용하는 데 사용됩니다. 

def is_triopical(sentence):
    if 'tropical' in sentence:
        return True
    else :
        return False

def is_fruity(sentence):
    if 'fruity' in sentence:
        return True
    else :
        return False

a = reviews['description'].apply(is_triopical).sum()   #apply : description에 함수 내용대로 값을 반환해라

b = reviews['description'].apply(is_fruity).sum()

c = pd.Series({'tropical': a, 'fruity': b})

c
# Out:
# tropical    3607
# fruity      9090
# dtype: int64

# %% [markdown]
# 별점 시스템을 만들려고 한다. 따라서 별점에 대한 데이터가 필요하다.
#
# 별점은 1,2,3 즉 3개로 만들것이다.
#
# 포인트가 95점 이상이면 3점, 85점 이상이면 2점, 나머지는 1점으로 할 것이다.
#
# 리뷰데이터를 통해 각 데이터의 별점을 구하시오.

# %%
def point(sentence):
    if sentence>= 95 :
        return 3
    elif 95>sentence>=85:
        return 2
    else:
        return 1


reviews['star'] =reviews['points'].apply(point)
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 129966    2
# 129967    2
# 129968    2
# 129969    2
# 129970    2
# Name: star, Length: 129971, dtype: int64

# %% [markdown]
# 리뷰의 region_2 컬럼에 데이터가 비어있는 경우에는, 'Unknown'으로 셋팅하자.

# %%
reviews['region_2'].fillna('Unknown', inplace=True)  
# fillna() 함수는 결측치를 다른 값으로 대체하는 데 사용되는 함수입니다. fillna() 함수를 사용하기 위해 필요한 매개변수는 대체할 값 또는 대체 방법에 따라 달라집니다.
reviews
# Out:
#          country                                        description
# 0          Italy  Aromas include tropical fruit, broom, brimston...  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price
# 0                                 Vulkà Bianco      87    NaN  \
# ...

# %% [markdown]
# 각 포인트 별로, 몇개의 리뷰가 있는가?
# 예를 들어 95점은 4개, 94점은 10개 등등... 알고 싶은 경우

# %%
reviews['points'].value_counts()
# Out:
# points
# 88     17207
# 87     16933
# 90     15410
# 86     12600
# 89     12226
# 91     11359
# 92      9613
# 85      9530
# 93      6489
# 84      6480
# 94      3758
# 83      3025
# 82      1836
# 95      1535
# 81       692
# 96       523
# 80       397
# 97       229
# 98        77
# 99        33
# 100       19
# Name: count, dtype: int64

# %%
reviews.groupby('points')['points'].count().sort_values()
# Out:
# points
# 100       19
# 99        33
# 98        77
# 97       229
# 80       397
# 96       523
# 81       692
# 95      1535
# 82      1836
# 83      3025
# 94      3758
# 84      6480
# 93      6489
# 85      9530
# 92      9613
# 91     11359
# 89     12226
# 86     12600
# 90     15410
# 87     16933
# 88     17207
# Name: points, dtype: int64

# %% [markdown]
# 가장 점수가 높은 와인은?

# %%
reviews['points'].max()
# Out:
# 100

# %%
reviews['points'] == reviews['points'].max()
reviews.loc[reviews['points'] == reviews['points'].max(), ]
# Out:
#           country                                        description
# 345     Australia  This wine contains some material over 100 year...  \
# 7335        Italy  Thick as molasses and dark as caramelized brow...
# 36528      France  This is a fabulous wine from the greatest Cham...
# 39286       Italy  A perfect wine from a classic vintage, the 200...
# 42197    Portugal  This is the latest release of what has long be...
# 45781       Italy  This gorgeous, fragrant wine opens with classi...
# 45798          US  Tasted in a flight of great and famous Napa wi...
# 58352      France  This is a magnificently solid wine, initially ...
# 89728      France  This latest incarnation of the famous brand is...
# 89729      France  This new release from a great vintage for Char...
# 111753     France  Almost black in color, this stunning wine is g...
# 111754      Italy  It takes only a few moments before you appreci...
# 111755     France  This is the finest Cheval Blanc for many years...
# ...

# %%
max_points = reviews['points'].max()
title = reviews.loc[reviews['points'] == max_points, 'title']
title
# Out:
# 345       Chambers Rosewood Vineyards NV Rare Muscat (Ru...
# 7335      Avignonesi 1995 Occhio di Pernice  (Vin Santo ...
# 36528                           Krug 2002 Brut  (Champagne)
# 39286     Tenuta dell'Ornellaia 2007 Masseto Merlot (Tos...
# 42197         Casa Ferreirinha 2008 Barca-Velha Red (Douro)
# 45781     Biondi Santi 2010 Riserva  (Brunello di Montal...
# 45798       Cardinale 2006 Cabernet Sauvignon (Napa Valley)
# 58352            Château Léoville Barton 2010  Saint-Julien
# 89728     Louis Roederer 2008 Cristal Vintage Brut  (Cha...
# 89729     Salon 2006 Le Mesnil Blanc de Blancs Brut Char...
# 111753             Château Lafite Rothschild 2010  Pauillac
# 111754    Casanova di Neri 2007 Cerretalto  (Brunello di...
# 111755             Château Cheval Blanc 2010  Saint-Émilion
# 111756        Château Léoville Las Cases 2010  Saint-Julien
# 113929    Charles Smith 2006 Royal City Syrah (Columbia ...
# 114972        Quinta do Noval 2011 Nacional Vintage  (Port)
# ...

# %% [markdown]
# 점수는 높고 가격은 싼 와인 순으로 보여주시오

# %%
reviews['price']
# Out:
# 0          NaN
# 1         15.0
# 2         14.0
# 3         13.0
# 4         65.0
#           ...
# 129966    28.0
# 129967    75.0
# 129968    30.0
# 129969    32.0
# 129970    21.0
# Name: price, Length: 129971, dtype: float64

# %%
reviews.sort_values(['points', 'price'], ascending=[False,True]) #포인트는 오름차순 가격은 내림차순
# Out:
#          country                                        description
# 113929        US  In 2005 Charles Smith introduced three high-en...  \
# 123545        US  Initially a rather subdued Frog; as if it has ...
# 58352     France  This is a magnificently solid wine, initially ...
# 45798         US  Tasted in a flight of great and famous Napa wi...
# 7335       Italy  Thick as molasses and dark as caramelized brow...
# ...          ...                                                ...
# 122417        US  There's little going on in this wine beyond su...
# 28569         US  Smells and tastes like caramel and stewed cher...
# 103989        US  This suffers from major problems. It has all t...
# 117025  Portugal  A curious sauerkraut perfume leads to a hard e...
# 123541     Italy  This Valpolicella blend opens with an aged, br...
#
#                  designation  points  price    province
# 113929            Royal City     100   80.0  Washington  \
# ...

# %% [markdown]
# 포인트별로 가격의 최소값을 구해본다
# 이것을 구하면 100점짜리 와인을 먹으려면 최소한 얼마가 있어야 하는지 파악이 가능함.

# %%
reviews.groupby('points')['price'].min()
# Out:
# points
# 80      5.0
# 81      5.0
# 82      4.0
# 83      4.0
# 84      4.0
# 85      4.0
# 86      4.0
# 87      5.0
# 88      6.0
# 89      7.0
# 90      8.0
# 91      7.0
# 92     11.0
# 93     12.0
# 94     13.0
# 95     20.0
# 96     20.0
# 97     35.0
# 98     50.0
# 99     44.0
# 100    80.0
# Name: price, dtype: float64

# %%
import numpy as np
reviews.groupby('points')['price'].agg([np.min, np.max]).sort_index(ascending=False)  #agg : numpy 함수로 여러가지 계산
# Out:
#         amin    amax
# points
# 100     80.0  1500.0
# 99      44.0   850.0
# 98      50.0  1900.0
# 97      35.0  2000.0
# 96      20.0  2500.0
# 95      20.0   973.0
# 94      13.0  1125.0
# 93      12.0   770.0
# 92      11.0   750.0
# 91       7.0  2013.0
# 90       8.0   510.0
# 89       7.0   500.0
# 88       6.0  3300.0
# 87       5.0   800.0
# 86       4.0   170.0
# 85       4.0   320.0
# 84       4.0   225.0
# 83       4.0   225.0
# 82       4.0   150.0
# 81       5.0   130.0
# 80       5.0    69.0
