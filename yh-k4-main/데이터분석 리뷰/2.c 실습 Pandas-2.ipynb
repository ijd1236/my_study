# %%
import calendar
import numpy as np
import pandas as pd
#from pandas.core.frame import DataFrame
#from pandas.core.series import Series #이렇게 불러도 됨.
import seaborn as sns # 통계적 plot
from scipy import stats #통계
import missingno as msno #결측치 보는 plot
from datetime import datetime #day
import matplotlib.pyplot as plt
import warnings #에러는 아닌데 주희하는게 뜨는것을 방지.
warnings.filterwarnings('ignore')

# %% [markdown]
# winemag-data-130k-v2.csv 파일을 reviews 로 읽는다.

# %%
import pandas as pd

reviews = pd.read_csv('C:/Users/405/Desktop/yh-k4-main/data/winemag-data.csv', index_col= 0)
# index_col= 0 Unnamed를 없앤다
reviews
# Out:
#          country                                        description
# 0          Italy  Aromas include tropical fruit, broom, brimston...  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price
# 0                                 Vulkà Bianco      87    NaN  \
# ...

# %% [markdown]
# 인덱스를 title 컬럼으로 셋팅한다.

# %%
reviews.set_index('title', inplace=True)
reviews
# Out:
#                                                      country
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy  \
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
# ...                                                      ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...   Germany
# Citation 2004 Pinot Noir (Oregon)                         US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...  \
# ...

# %% [markdown]
# 먼저 데이터가 비어있느것이 있는지 확인한다.

# %%
reviews.isna()
# Out:
#                                                     country  description
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                     False        False  \
# Quinta dos Avidagos 2011 Avidagos Red (Douro)         False        False
# Rainstorm 2013 Pinot Gris (Willamette Valley)         False        False
# St. Julian 2013 Reserve Late Harvest Riesling (...    False        False
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...    False        False
# ...                                                     ...          ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...    False        False
# Citation 2004 Pinot Noir (Oregon)                     False        False
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)    False        False
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         False        False
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    False        False
#
#                                                     designation  points
# title
# ...

# %%
reviews.notna() #isna의 반대
# Out:
#                                                     country  description
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      True         True  \
# Quinta dos Avidagos 2011 Avidagos Red (Douro)          True         True
# Rainstorm 2013 Pinot Gris (Willamette Valley)          True         True
# St. Julian 2013 Reserve Late Harvest Riesling (...     True         True
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...     True         True
# ...                                                     ...          ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...     True         True
# Citation 2004 Pinot Noir (Oregon)                      True         True
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)     True         True
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)          True         True
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...     True         True
#
#                                                     designation  points
# title
# ...

# %% [markdown]
# 그리고나서, 가격이 없는 데이터는 빼고, 데이터셋을 가져온다.

# %%
reviews.dropna(subset=['price'])
# Out:
#                                                      country
# title
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal  \
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
# Tandem 2011 Ars In Vitro Tempranillo-Merlot (Na...     Spain
# ...                                                      ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...   Germany
# Citation 2004 Pinot Noir (Oregon)                         US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description
# title
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...  \
# ...

# %% [markdown]
# 리뷰에 새로운 컬럼 critic 만들고, everyone 이라고 값 넣는다.

# %%
reviews['critic']='everyone'

reviews
# Out:
#                                                      country
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy  \
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
# ...                                                      ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...   Germany
# Citation 2004 Pinot Noir (Oregon)                         US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...  \
# ...

# %% [markdown]
# 리뷰의 포인트 컬럼은 수치로 되어있다. 이 컬럼의 기초통계데이터를 확인하시오. (평균, 최대 최소 등)

# %%
reviews['points'].describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %% [markdown]
# taster_name 컬럼은 사람 이름으로 되어있다. 몇명의 사람들이 평가를 한것인까?

# %%
reviews['taster_name'].nunique()
# Out:
# 19

# %% [markdown]
# 리뷰 포인트의 평균을 구하시오

# %%
reviews['points'].mean()
# Out:
# 88.44713820775404

# %% [markdown]
# 테스터들의 이름을 전부 확인하시오

# %%
reviews['taster_name'].unique()  #넘파이 출력, 데이터 프레임은 행,과 열이 넘파이를 감싸는 형태
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
reviews.groupby('taster_name')['taster_name'].count() #시리즈 출력
# Out:
# taster_name
# Alexander Peartree      415
# Anna Lee C. Iijima     4415
# Anne Krebiehl MW       3685
# Carrie Dykes            139
# Christina Pickard         6
# Fiona Adams              27
# Jeff Jenssen            491
# Jim Gordon             4177
# Joe Czerwinski         5147
# Kerin O’Keefe         10776
# Lauren Buzzeo          1835
# Matt Kettmann          6332
# Michael Schachner     15134
# Mike DeSimone           514
# Paul Gregutt           9532
# Roger Voss            25514
# Sean P. Sullivan       4966
# Susan Kostrzewa        1085
# Virginie Boone         9537
# Name: taster_name, dtype: int64

# %%
reviews['taster_name'].value_counts()
# Out:
# taster_name
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: count, dtype: int64

# %% [markdown]
# 각 테스터들은, 각각 몇개의 와인을 테스트 했는지 확인하시오. ( 테스터 이름, 갯수 )

# %% [markdown]
# 리뷰의 포인트의 평균을 구하고, 리뷰의 포인트값이, 평균보다 큰 데이터 (즉, 평가가 좋은 와인) 만 가져오시오.

# %%
reviews[reviews['points'] > reviews['points'].mean() ]
# Out:
#                                                       country
# title
# Dopff & Irion 2004 Schoenenbourg Grand Cru Vend...     France  \
# Ceretto 2003 Bricco Rocche Prapó  (Barolo)              Italy
# Matrix 2007 Stuhlmuller Vineyard Chardonnay (Al...         US
# Mauritson 2007 Rockpile Cemetary Vineyard Zinfa...         US
# Henry's Drive Vignerons 2006 Parson's Flat Shir...  Australia
# ...                                                       ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...    Germany
# Citation 2004 Pinot Noir (Oregon)                          US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)     France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)          France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...     France
#
#                                                                                           description
# title
# Dopff & Irion 2004 Schoenenbourg Grand Cru Vend...  Medium-gold in color. Complex and inviting nos...  \
# ...
